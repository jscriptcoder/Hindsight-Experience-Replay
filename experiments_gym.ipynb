# %%
import torch
import gym
import gym.spaces

# %%
env = gym.make('FetchSlide-v1')
# Out:
# Compiling /Users/franciscoramos/Personal/mujoco-py/mujoco_py/cymj.pyx because it changed.
# [1/1] Cythonizing /Users/franciscoramos/Personal/mujoco-py/mujoco_py/cymj.pyx
# running build_ext
# building 'mujoco_py.cymj' extension
# creating /Users/franciscoramos/Personal/mujoco-py/mujoco_py/generated/_pyxbld_2.0.2.10_38_macextensionbuilder
# creating /Users/franciscoramos/Personal/mujoco-py/mujoco_py/generated/_pyxbld_2.0.2.10_38_macextensionbuilder/temp.macosx-10.9-x86_64-3.8
# creating /Users/franciscoramos/Personal/mujoco-py/mujoco_py/generated/_pyxbld_2.0.2.10_38_macextensionbuilder/temp.macosx-10.9-x86_64-3.8/Users
# creating /Users/franciscoramos/Personal/mujoco-py/mujoco_py/generated/_pyxbld_2.0.2.10_38_macextensionbuilder/temp.macosx-10.9-x86_64-3.8/Users/franciscoramos
# creating /Users/franciscoramos/Personal/mujoco-py/mujoco_py/generated/_pyxbld_2.0.2.10_38_macextensionbuilder/temp.macosx-10.9-x86_64-3.8/Users/franciscoramos/Personal
# ...
